# %% [markdown]
# <a href="https://colab.research.google.com/github/Barni024/Keras-fashion/blob/master/Fashion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Keras sequential learning

# %% [markdown]
# Importing libraries

# %%
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Load and prepare dataset

# %%
data = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = data.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandals', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

train_images = train_images/255.0
test_images = test_images/255.0
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# Prepering neural network

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dense(10, activation="softmax")
    ])

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %% [markdown]
# Training neural network

# %%
model.fit(train_images, train_labels, epochs=15)
# Out:
# Train on 60000 samples
# Epoch 1/15
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.4951 - accuracy: 0.8257
# Epoch 2/15
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.3697 - accuracy: 0.8662
# Epoch 3/15
# 60000/60000 [==============================] - 4s 69us/sample - loss: 0.3312 - accuracy: 0.8785
# Epoch 4/15
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.3072 - accuracy: 0.8869
# Epoch 5/15
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.2910 - accuracy: 0.8934
# Epoch 6/15
# 60000/60000 [==============================] - 4s 67us/sample - loss: 0.2760 - accuracy: 0.8971
# Epoch 7/15
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.2645 - accuracy: 0.9020
# Epoch 8/15
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.2544 - accuracy: 0.9053
# Epoch 9/15
# ...

# %% [markdown]
# Calculating and printing loss and accuracy

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)

print("Tested loss: ",test_loss)

print("Tested acc: ", test_acc)
# Out:
# 10000/10000 [==============================] - 1s 68us/sample - loss: 0.3539 - accuracy: 0.8818
# Tested loss:  0.3538946763575077
# Tested acc:  0.8818

# %% [markdown]
# Visualising accual results

# %%
predictions = model.predict(test_images)

plt.figure(figsize=(5,5))
for i in range(15):
  plt.imshow(test_images[i], cmap=plt.cm.binary)
  plt.xlabel(class_names[test_labels[i]])
  plt.title(class_names[np.argmax(predictions[i])])
  plt.show()
